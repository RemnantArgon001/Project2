# %% [markdown]
# First choice:
#
# 1) Source of data:https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/
#
# 2) Brief description of data
#
# 3) What is the target? status
#
# 4) Is this a classification or regression problem?classification
#
# 5) How many features? 24
#
# 6) How many rows of data: 195
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset? name for collumn's and imputer

# %%
import pandas as pd
import numpy as np

# %%
names_df=pd.read_csv('/parkinsons.data')
names_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
Parkinsons_df.shape
# Out:
# (195, 24)

# %% [markdown]
# Second choice: electric vehicle by zip
#
# 1) Source of data https://catalog.data.gov/dataset/electric-vehicle-population-data
#
# 2) Brief description of data :This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
#
# 3) What is the target? state
#
# 4) Is this a classification or regression problem? Classification
#
# 5) How many features?16
#
# 6) How many rows of data.91933
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset? fear of for loop such large data could take forever to load.

# %%
df=pd.read_csv('/Electric_Vehicle_Population_Data.csv')

# %%
df.head()
# Out:
#    VIN (1-10)     County          City State  ZIP Code  Model Year       Make  \
# 0  1G1RC6E45F   Thurston        TENINO    WA     98589        2015  CHEVROLET
# 1  5YJSA1E26J  Snohomish      MUKILTEO    WA     98275        2018      TESLA
# 2  5YJSA1E26K     Camden   SAINT MARYS    GA     31558        2019      TESLA
# 3  1G1FW6S03H   Thurston         LACEY    WA     98503        2017  CHEVROLET
# 4  1N4AZ0CP6D     Skagit  MOUNT VERNON    WA     98273        2013     NISSAN
#
#      Model                   Electric Vehicle Type  \
# 0     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  MODEL S          Battery Electric Vehicle (BEV)
# 2  MODEL S          Battery Electric Vehicle (BEV)
# 3  BOLT EV          Battery Electric Vehicle (BEV)
# 4     LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              38
# ...

# %%
df.shape
# Out:
# (91933, 16)
